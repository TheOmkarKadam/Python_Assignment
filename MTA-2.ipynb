# %%
#2
#from sys import argv
#sum = 0
#for i in range (2,len(argv)):
#    sum += float(argv[i])
#print("The Average for {0} is {1:.2f}".format(argv[1],sum/(len(argv)-2)))

#run in terminal

# %%
#3
x=3
x+=1

#x = 16

x**=2
print(x)
# Out:
# 16

# %%
#5
a = ['a','b','c','d']
for i in a:
    a.append(i.upper())
    break
print(a)
#without break memory updation and crashes
# Out:
# ['a', 'b', 'c', 'd', 'A']

# %%
#6
a = '5'
b = '2'

#str operations
print(a*2)
print(a+b)
# Out:
# 55
# 52

# %%
#8
a=7
b=3
c=5
d=1

#ans is 9
op = a+d*2
print(op)
# Out:
# 9

# %%
#10
6//4%5+2**3-2//3
# Out:
# 9

# %%
#11
x = 'text'
#op = 'TT'

op = x[0]+x[-1]
op1 = x[-1]+x[3]
print(op)
print(op1)
# Out:
# tt
# tt

# %%
#12
print(10==10 and 20!=20)
print(10==10 or 20!=20)
print(not 10 == 10)
# Out:
# False
# True
# False

# %%
#13
a = float('123.456')

#ans 2

bool(a) + True
# Out:
# 2

# %%
#14

#create a fun to calculate the avg velocity on a 2640 foot track 

dis = float(input("Enter the distance travelled in feet:"))
dis_mil = dis/5280
time = int(input("Enter time travelled in seconds :"))
time_hours = time/3600
vel = dis_mil/time_hours
print("The average velocity is ",vel,'miles/hours')
# Out:
# Enter the distance travelled in feet: 5467
# Enter time travelled in seconds : 67
# The average velocity is  55.63432835820896 miles/hours

# %%
#15
# take a value in any format but use only whole number of the value
val = int(float(input("How many items are rerquired ?")))
print(val)
# Out:
# How many items are rerquired ? 788.234
# 788

# %%
#16
#print true

print('r' in 'durga')
print('is' in 'This IS a fake news')
# Out:
# True
# True

# %%
#17
x = 2 
y = 6
x += 2**3
x//=y//2//3
print(x)
# Out:
# 10

# %%
#19

#inp = 12345
#op = 12346

count = int(input("Enter count value :"))
print(count+1)
# Out:
# Enter count value : 12345
# 12346

# %%
#20
t = ([10,20],10,False)
print(type(t[0]))
# Out:
# <class 'list'>

# %%
#24
res = str(bool(1) + float(10)/float(2))
print(res)
# Out:
# 6.0

# %%
#25

#take and print a name

name = input("Enter your name :")
print(name)
# Out:
# Enter your name : Omkar
# Omkar

# %%
#27
print(not 0)
print(not 10)
print(not '')
print(not 'durga')
print(not None)
# Out:
# True
# False
# True
# False
# True

# %%
#30
s = "Durga soft"

# res is 9

res = len(s.replace(" ",''))
print(res)
# Out:
# 9

# %%
#34
v1 = 1
v2 = 0
v1 = v1 ^ v2
v2 = v1 ^ v2
v1 = v1 ^ v2
print(v1)
# Out:
# 0

# %%
#37

s1 = 'Bharat \n software \n solutions'
print(s1)

s2 = '''Bharat
software 
solutions'''
print(s2)
# Out:
# Bharat
#  software
#  solutions
# Bharat
# software
# solutions

# %%
#38
l = [7,8,9]
b = l[:]
print(l is b)
print(l == b)
# Out:
# False
# True

# %%
#40\

#op = Welcome to Bharat soft in Pune

name = (input("Enter your college name :"))
city = (input("Enter your city name :"))

print("Welcome to {} in {}".format(name,city))
# Out:
# Enter your college name : Bharat Soft
# Enter your city name : Pune
# Welcome to Bharat Soft  in Pune
