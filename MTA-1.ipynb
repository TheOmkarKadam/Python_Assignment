# %%
#1
x = 8
y = 10
res = x//3*3/2+y%2**2
print(res)
# Out:
# 5.0

# %%
#2
start = input("How old were you at the time of joining ?")
end = input("How old are you today")
print("Congratulations on "+str(int(end)-int(start))+" years of service")
# Out:
# How old were you at the time of joining ? 23
# How old are you today 36
# Congratulations on 13 years of service

# %%
#3
x = "ACROTE"
y = "APPLE"
z= "TOMATO" 
#print CAT
print(x[-5]+y[0]+z[0])
print(x[1]+y[0]+z[0])
print(x[-5]+y[0]+z[-2])

#won't print CAT
print(x[2]+y[1]+z[2])
# Out:
# CAT
# CAT
# CAT
# RPM

# %%
#4
x = 'Durga'
y = 'Durga'
condn = (x is y)
res = condn
print(res)
# Out:
# True

# %%
#5
a1 = '10'
b1 = 3
c1 = a1*b1
print(type (c1))

a2 = 10
b2 = 3
c2 = a2/b2
print(type (c2))

a3 = 2.6
b3 = 1 
c3 = a3/b3
print(type(c3))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'float'>

# %%
#6
#SAME RESULT
print(13//4)
print(11/3) #float 3.6666
print(3**1)
print(23%5)
# Out:
# 3
# 3.6666666666666665
# 3
# 3

# %%
#7
n1 = [10,20,30,40,50]
n2 =[10,20,30,40,50]
print(n1 is n2) #only str and int point to same obj rest point to different obj in memory
print(n1 == n2)
# Out:
# False
# True

# %%
#8
a = 1
b = 3
c = 5
d = 7

# result 0
print(a%b-1)
print(a**d-1)

#not 0
print(a+b*2)
print(a-b//d)
# Out:
# 0
# 0
# 7
# 1

# %%
#9
s = 'AB CD'
list = list(s)
list.append("EF")
print (list)
# Out:
# ['A', 'B', ' ', 'C', 'D', 'EF']

# %%
#10
a = 5
b = 10
c = 2
d = True

x = a+b*c #25
y = a+b/d #15

if (x>y):
    print("valid")
else:
    print("Invalid")
# Out:
# valid

# %%
#11
x = input("Enter first number :")
y = input("Enter second number :")

print("The Result is "+ str(int(x)+int(y)))
# Out:
# Enter first number : 23
# Enter second number : 23
# The Result is 46

# %%
#12
res = a-b*c+d
#same as 
res = a-(b*c)+d

# %%
#13
weight = 62.4
zip = '80098'
value =+ 23e4

print(type(weight))
print(type(zip))
print(type(value))
# Out:
# <class 'float'>
# <class 'str'>
# <class 'float'>

# %%
#14
a = 10+20 #30
b = '10'+ '20' #"1020"
c = '10' * 3 #"101010"

print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'str'>

# %%
#15
a = bool([False]) 
b = bool(3)
c = bool("")
d = bool(" ")

print(a,b,c,d)
# Out:
# True True False True

# %%
#16
res = (2*(3+4)**2-(3**3)*3)
print(res)
# Out:
# 17

# %%
#17
a = 2 
a += 1

#to make value 9

a **=2
print(a)
# Out:
# 9

# %%
#18
a = bool(0)
b = bool(3)
c = bool(0.5)
d = bool(0.0)

print(a,b,c,d)
# Out:
# False True True False

# %%
#19
a = 21
b = 6
print(a/b)
print(a//b)
print(a%b)
# Out:
# 3.5
# 3
# 3

# %%
#20
# 500 emp last 3 management 
#get only management

#emps[-3:]
#emps[497:]
#emps[497:500]

# %%
#21
sub = ['Java','Python','SAP']
mo_sub = ['Java','Python','SAP']
ext_sub = mo_sub 

#TRUE
print(ext_sub is mo_sub)
print(sub == ext_sub)

#FALSE
print(sub is mo_sub)
print(sub is ext_sub)
# Out:
# True
# True
# False
# False

# %%
#22
# 500 emps to access employee without error
#emp[0:501]
#emp[1:100]
#emp[-10:10]
#slice operator never raises error

# %%
#23
n = [10,20,30,40,50]
a = ['a','b','c','d','e']
print(n is a)
print (n == a)
n = a
print(n is a)
print (n == a)
# Out:
# False
# False
# True
# True

# %%
#24
age = 0
minor = False
name = 'Durga'

#types
print(type(age))
print(type(minor))
print(type(name))
# Out:
# <class 'int'>
# <class 'bool'>
# <class 'str'>

# %%
#25 
# to generate max value
print(8//3*4)
print(8-3*4)
print(8%3*4)
print(8/3*4)
# Out:
# 8
# -4
# 8
# 10.666666666666666

# %%
#26
s ='Python is easy'
s1 = s[6:-4]
s2 = s1.strip()
print(s2)
print(len(s2))
# Out:
# is
# 2

# %%
#27 
#600 emps without taking last 3 emps
#emps[:-3]
#emps[0:-3]

# %%
#28
l = ['Apple','Banana','Carrot','Mango']
# access Mango

l[-1]
l[3]
# Out:
# 'Mango'

# %%
#29
l = ['Apple','Boy','Cat','Dog']
for x in l:
    if len(x) == 3:
        print(x)

l1=l[1:]
for x in l1:
    print(x)
# Out:
# Boy
# Cat
# Dog
# Boy
# Cat
# Dog

# %%
#30
a = 15
b = 5
print(a/b)
# Out:
# 3.0

# %%
#31
#500 emps error 
#emps[500] out of range

# %%
#32
a=1
b=2
c=4
d=6

print((a+b)//c*d)
print((b+c)//a%d)
print((a+b)//c%d)
print((a+b)//d-c)
# Out:
# 0
# 0
# 0
# -4

# %%
#33
s= 'Python is easy'
s1 = s[-7:]
s2 = s[-4:]
print(s1+s2)
# Out:
# is easyeasy

# %%
#36
res = 8//6%5+2**3-2
print(res)
# Out:
# 7

# %%
#37
a = 3
b = 5
a +=2**3
a -=b//2//3
print(a)
# Out:
# 11

# %%
#38
a = bool([])
b = bool(())
c = bool(range(0))
d = bool({})
e = bool(set())

print(a,b,c,d,e)
# Out:
# False False False False False

# %%
#39
num = [10,20,30,40]
x = 0

for i in(30,40,50):
    if i in num:
        x = x+5
print(x)

x= 0

for i in (30,40,50):
    if i not in num:
        x = x+10
print(x)
# Out:
# 10
# 10
